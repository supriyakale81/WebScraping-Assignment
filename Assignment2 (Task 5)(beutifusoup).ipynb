# %% [markdown]
# ### Scrape 100 reviews data from flipkart.com for iphone11 phone. You have to go the link:
# https://www.flipkart.com/apple-iphone-11-black-64-gb/productreviews/itm4e5041ba101fd?pid=MOBFWQ6BXGJCEYNY&lid=LSTMOBFWQ6BXGJCEYNYZXSHRJ&marketplace=FLIPKART
# #### As shown in the above page you have to scrape the tick marked attributes. These are:
# 1. Rating
# 2. Review summary
# 3. Full review
# 4. You have to scrape this data for first 100reviews.

# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests
import time

# %%
page=requests.get("https://www.flipkart.com/apple-iphone-11-black-64-gb/product-reviews/itm4e5041ba101fd?pid=MOBFWQ6BXGJCEYNY&lid=LSTMOBFWQ6BXGJCEYNYZXSHRJ&market")

# %%
page
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(page.content,'html.parser')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# ...

# %%
ratings=[]
rating=soup.find_all('div',class_="_3LWZlK _1BLPMq")
for i in rating:
    ratings.append(i.text)

# %%
print(ratings)
# Out:
# ['5', '5', '5', '4', '5', '5', '5', '5', '4', '5']

# %%
review_summary=[]
review=soup.find_all('p',class_="_2-N8zT")
for i in review:
    review_summary.append(i.text)

# %%
print(review_summary)
# Out:
# ['Simply awesome', 'Perfect product!', 'Best in the market!', 'Value-for-money', 'Highly recommended', 'Worth every penny', 'Perfect product!', 'Highly recommended', 'Pretty good', 'Great product']

# %%
full_review=[]
f_review=soup.find_all('div',class_="t-ZTKy")
for i in f_review:
    full_review.append(i.getText('#text'))

# %%
print(full_review)
# Out:
# ['Really satisfied with the Product I received... It’s totally genuine and the packaging was also really good so if ur planning to buy just go for it.#textREAD MORE', 'Amazing phone with great cameras and better battery which gives you the best performance. I just love the camera .#textREAD MORE', 'Great iPhone very snappy experience as apple kind. Upgraded from iPhone 7. #textPros#text-Camera top class #text- Battery top performed #text-Chipset no need to say as apple kind #text-Security as you expect from apple #text- Display super bright industry leading colour #text  accuracy and super responsive #text-Build quality as expect from apple sturdy#text  premium durable beautiful stylish. #text-Os most stable os in smartphone industry #textCons #text-No 5G#text-Display is not based on OLED technology #text-Charger headphones and 1 apple stic...#textREAD MORE', "I'm Really happy with the product#textDelivery was fast as well#text..it was a gift for my sister and she loved it so much.#t
# ...

# %%
len(full_review)
# Out:
# 10

# %%
ratings1=[]
review_summary1=[]
full_review1=[]

# %%
for x in range (0,11):
    rating=soup.find_all('div',class_="_3LWZlK _1BLPMq")
    for i in rating[0:100]:
        ratings1.append(i.text)
    review=soup.find_all('p',class_="_2-N8zT")
    for i in review[0:100]:
        review_summary1.append(i.text)
    f_review=soup.find_all('div',class_="t-ZTKy")
    for i in f_review[0:100]:
        full_review1.append(i.getText('#text'))
    but=soup.find('a',class_="_1LKTO3")
    but.()
    time.sleep(3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_34776\2112589112.py in <module>
#      10         full_review1.append(i.getText('#text'))
#      11     but=soup.find('a',class_="_1LKTO3")
# ---> 12     but.click()
#      13     time.sleep(3)
#
# TypeError: 'NoneType' object is not callable
