# %% [markdown]
# ### Write a python program to scrape cricket rankings from icc-cricket.com. You have to scrape and make data frame
#
# #### a) Top 10 ODI teams in men’s cricket along with the records for matches, points and rating.
# #### b) Top 10 ODI Batsmen along with the records of their team and rating.
# #### c) Top 10 ODI bowlers along with the records of their team and rating

# %%
import bs4
from bs4 import BeautifulSoup
import requests

# %%
page=requests.get("https://www.icc-cricket.com/rankings/mens/player-rankings/test")
page
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(page.content,'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta content="ICC Men's Test Player Rankings | ICC" name="twitter:title"/>
# <meta content="website" property="og:type"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="Official International Cricket Council rankings for test match cricket players. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="description"/>
# <meta content="@icc" property="twitter:site"/>
# <meta content="Official International Cricket Council rankings for test match cricket players. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="twitter:description"/>
# <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
# <meta content="ICC Men's Test Player Rankings | ICC" property="og:title"/>
# ...

# %% [markdown]
# #### a) Top 10 ODI teams in men’s cricket along with the records for matches, points and rating.

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By

# %%
# connect to the driver
driver = webdriver.Chrome(r"C:\Users\pc\Downloads\chromedriver_win32\chromedriver.exe")
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_22996\80213923.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(r"C:\Users\pc\Downloads\chromedriver_win32\chromedriver.exe")

# %%
# scraping the naukri page automated chrome browser
driver.get("https://www.icc-cricket.com/rankings/mens/player-rankings/test")

# %%
search=driver.find_element(By.XPATH,'/html/body/div[2]/header/section[2]/div[2]/div/nav/a[3]')
search.click()

# %%
ODI=driver.find_element(By.XPATH,'/html/body/main/div/div[2]/section/div/div/div/ul/li[2]/a')
ODI.click()

# %%
rank=driver.find_element(By.XPATH,'//div[@class="drop-down-tablet js-drop-down"]')
rank.click()

# %%
rankte=driver.find_element(By.XPATH,'/html/body/main/div/div[1]/div/div/div[4]/div[2]/ul/li[3]/a')
rankte.click()

# %%
odi=driver.find_element(By.XPATH,'/html/body/main/div/div[2]/section/div/div/div/ul/li[2]/a')
odi.click()

# %%
team=driver.find_element(By.XPATH,'/html/body/main/div/div[2]/div/div/section/div[3]/table/tbody/tr[1]/td[2]/span[2]')
team.text
# Out:
# 'India'

# %%
matches=driver.find_element(By.XPATH,'/html/body/main/div/div[2]/div/div/section/div[3]/table/tbody/tr[1]/td[3]')
matches.text
# Out:
# '44'

# %%
points=driver.find_element(By.XPATH,'//td[@class="rankings-block__banner--points"]')
points.text
# Out:
# '5,010'

# %%
rating=driver.find_element(By.XPATH,'//td[@class="rankings-block__banner--rating u-text-right"]')
rating.text
# Out:
# '114'

# %%
teams=[]
team=driver.find_elements(By.XPATH,'//span[@class="u-hide-phablet"]')
for i in team[0:10]:
    teams.append(i.text)
print(teams)
# Out:
# ['India', 'Australia', 'New Zealand', 'England', 'Pakistan', 'South Africa', 'Bangladesh', 'Sri Lanka', 'Afghanistan', 'West Indies']

# %%
Matches=[]
matches=driver.find_elements(By.XPATH,'/html/body/main/div/div[2]/div/div/section/div[3]/table/tbody/tr/td[3]')
for i in matches[0:10]:
    Matches.append(i.text)
print(Matches)
# Out:
# ['44', '32', '29', '33', '25', '27', '33', '34', '20', '41']

# %%
points=[]
point=driver.find_elements(By.XPATH,'/html/body/main/div/div[2]/div/div/section/div[3]/table/tbody/tr/td[4]')
for i in point[0:10]:
    points.append(i.text)
print(points)
# Out:
# ['5,010', '3,572', '3,229', '3,656', '2,649', '2,775', '3,129', '2,976', '1,419', '2,902']

# %%
ratings=[]
rate=driver.find_elements(By.XPATH,'/html/body/main/div/div[2]/div/div/section/div[3]/table/tbody/tr/td[5]')
for i in rate[0:10]:
    ratings.append(i.text)
print(ratings)
# Out:
# ['114', '112', '111', '111', '106', '103', '95', '88', '71', '71']

# %%
print(len(teams),len(Matches),len(points),len(ratings))
# Out:
# 10 10 10 10

# %%
import pandas as pd
data=pd.DataFrame({"Teams":teams,"Matches":Matches,'Points':points,"Ratings":ratings})
data
# Out:
#           Teams Matches Points Ratings
# 0         India      44  5,010     114
# 1     Australia      32  3,572     112
# 2   New Zealand      29  3,229     111
# 3       England      33  3,656     111
# 4      Pakistan      25  2,649     106
# 5  South Africa      27  2,775     103
# 6    Bangladesh      33  3,129      95
# 7     Sri Lanka      34  2,976      88
# 8   Afghanistan      20  1,419      71
# 9   West Indies      41  2,902      71

# %% [markdown]
# #### b) Top 10 ODI Batsmen along with the records of their team andrating.

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By

# %%
# connect to the driver
driver = webdriver.Chrome(r"C:\Users\pc\Downloads\chromedriver_win32\chromedriver.exe")

# scraping the naukri page automated chrome browser
driver.get("https://www.icc-cricket.com/rankings/mens/player-rankings/test")
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_5768\778088835.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(r"C:\Users\pc\Downloads\chromedriver_win32\chromedriver.exe")

# %%
search=driver.find_element(By.XPATH,'/html/body/div[2]/header/section[2]/div[2]/div/nav/a[3]')
search.click()

# %%
ODI=driver.find_element(By.XPATH,'/html/body/main/div/div[2]/section/div/div/div/ul/li[2]/a')
ODI.click()

# %%
Players=[]
ratings=[]
teams=[]

# %%
player1=driver.find_element(By.XPATH,'//div[@class="rankings-block__banner--name"]')
Players.append(player1.text)

# %%
team1=team=driver.find_element(By.XPATH,'//div[@class="rankings-block__banner--nationality"]')
teams.append(team1.text.split("\n")[0])

# %%
rating1=driver.find_element(By.XPATH,'//div[@class="rankings-block__banner--rating"]')
ratings.append(rating1.text)

# %%
player=driver.find_elements(By.XPATH,'//td[@class="table-body__cell name"]')
for i in player[0:10]:
    Players.append(i.text)
print(Players)
# Out:
# ['Babar Azam', 'Rassie van der Dussen', 'David Warner', 'Quinton de Kock', 'Imam-ul-Haq', 'Shubman Gill', 'Virat Kohli', 'Steve Smith', 'Rohit Sharma', 'Kane Williamson', 'Josh Hazlewood']

# %%
team=driver.find_elements(By.XPATH,'//span[@class="table-body__logo-text"]')
for i in team[0:10]:
    teams.append(i.text)
print(teams)
# Out:
# ['PAK', 'SA', 'AUS', 'SA', 'PAK', 'IND', 'IND', 'AUS', 'IND', 'NZ', 'AUS']

# %%
rate=driver.find_elements(By.XPATH,'//td[@class="table-body__cell u-text-right rating"]')
for i in rate[0:10]:
    ratings.append(i.text)
print(ratings)
# Out:
# ['887', '787', '747', '743', '740', '734', '727', '719', '719', '700', '727']

# %%
import pandas as pd
data=pd.DataFrame({"Players":Players,"Teams":teams,"Ratings":ratings})
data
# Out:
#                   Players Teams Ratings
# 0              Babar Azam   PAK     887
# 1   Rassie van der Dussen    SA     787
# 2            David Warner   AUS     747
# 3         Quinton de Kock    SA     743
# 4             Imam-ul-Haq   PAK     740
# 5            Shubman Gill   IND     734
# 6             Virat Kohli   IND     727
# 7             Steve Smith   AUS     719
# 8            Rohit Sharma   IND     719
# 9         Kane Williamson    NZ     700
# 10         Josh Hazlewood   AUS     727

# %% [markdown]
# #### c) Top 10 ODI bowlers along with the records of their team and rating

# %%
Players=[]
ratings=[]
teams=[]

# %%
player1=driver.find_element(By.XPATH,'//div[@class="rankings-block__banner--name-large"]')
Players.append(player1.text)

# %%
team1=team=driver.find_element(By.XPATH,'//div[@class="rankings-block__banner--nationality"]')
teams.append(team1.text.split("\n")[0])

# %%
rating1=driver.find_element(By.XPATH,'//div[@class="rankings-block__banner--rating"]')
ratings.append(rating1.text)

# %%
team=driver.find_elements(By.XPATH,'//span[@class="table-body__logo-text"]')
for i in team[0:9]:
    teams.append(i.text)
print(teams)
# Out:
# ['IND', 'AUS', 'NZ', 'AUS', 'AFG', 'AUS', 'BAN', 'PAK', 'BAN', 'AFG']

# %%
player=driver.find_elements(By.XPATH,'//td[@class="table-body__cell rankings-table__name name"]')
for i in player[0:9]:
    Players.append(i.text)
print(Players)
# Out:
# ['Mohammed Siraj', 'Josh Hazlewood', 'Trent Boult', 'Mitchell Starc', 'Rashid Khan', 'Adam Zampa', 'Shakib Al Hasan', 'Shaheen Afridi', 'Mustafizur Rahman', 'Mujeeb Ur Rahman']

# %%
rate=driver.find_elements(By.XPATH,'//td[@class="table-body__cell rating"]')
for i in rate[0:9]:
    ratings.append(i.text)
print(ratings)
# Out:
# ['729', '727', '708', '665', '659', '655', '652', '641', '638', '637']

# %%
print(len(teams),len(Players),len(ratings))
# Out:
# 10 10 10

# %%
import pandas as pd
dataset=pd.DataFrame({"Players":Players,"Teams":teams,"Ratings":ratings})
dataset
# Out:
#              Players Teams Ratings
# 0     Mohammed Siraj   IND     729
# 1     Josh Hazlewood   AUS     727
# 2        Trent Boult    NZ     708
# 3     Mitchell Starc   AUS     665
# 4        Rashid Khan   AFG     659
# 5         Adam Zampa   AUS     655
# 6    Shakib Al Hasan   BAN     652
# 7     Shaheen Afridi   PAK     641
# 8  Mustafizur Rahman   BAN     638
# 9   Mujeeb Ur Rahman   AFG     637
